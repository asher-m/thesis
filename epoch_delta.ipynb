# %%
import matplotlib.pyplot as plt

# get *correct* data module for joyce-apj-tab2
import data_jat as data
# Out:
# This unreleased version of SpacePy is not supported by the SpacePy team.

# %%
d = data.Data('joyce-apj-background')
d.read_data(force_cache=True)
# Out:
# Found cached data from file eventdata_joyce-apj-background_20210420.pickle3.bz2, using contents...

# %%
d.datasets
# Out:
# {'psp_isois-epilo_l2-ic': {'ChanP': {'epoch': 'Epoch_ChanP',
#    'epoch_delta': 'Epoch_ChanP_DELTA',
#    'flux': 'H_Flux_ChanP',
#    'flux_unc': 'H_Flux_ChanP_DELTA',
#    'pa': 'PA_ChanP',
#    'energy': 'H_ChanP_Energy',
#    'energy_unc_plus': 'H_ChanP_Energy_DELTAPLUS',
#    'energy_unc_minus': 'H_ChanP_Energy_DELTAMINUS'}}}

# %%
plt.figure(figsize=(16, 9))

for i in range(0, 5):
    plt.plot((d.eventdata[i]['ChanP']['epoch'] - d.eventdata[i]['ChanP']['epoch'][0]) / 1e9,
             d.eventdata[i]['ChanP']['epoch_delta'] / 1e9,
             label=f'event {i}')

plt.xlabel('seconds from start')
plt.ylabel('delta seconds')
plt.legend()

# %%
plt.figure(figsize=(16, 9))

for i in range(5, 10):
    plt.plot((d.eventdata[i]['ChanP']['epoch'] - d.eventdata[i]['ChanP']['epoch'][0]) / 1e9,
             d.eventdata[i]['ChanP']['epoch_delta'] / 1e9,
             label=f'event {i}')

plt.xlabel('seconds from start')
plt.ylabel('delta seconds')
plt.legend()

# %%
plt.figure(figsize=(16, 9))

for i in range(10, 13):
    plt.plot((d.eventdata[i]['ChanP']['epoch'] - d.eventdata[i]['ChanP']['epoch'][0]) / 1e9,
             d.eventdata[i]['ChanP']['epoch_delta'] / 1e9,
             label=f'event {i}')

plt.xlabel('seconds from start')
plt.ylabel('delta seconds')
plt.legend()
